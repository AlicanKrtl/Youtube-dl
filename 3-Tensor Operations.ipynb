# %% [markdown]
# ## Tensor Operations

# %%
import numpy as np
import pandas as pd
from keras.activations import relu
# Out:
# Using TensorFlow backend.

# %%
input1 = np.array([[1,2,3,4],
                   [5,6,7,8]])
W = np.array([[-1.4, 0.87, -0.5, 0]]) #weight
b = 1.43

# %%
input1.shape, W.shape
# Out:
# ((2, 4), (1, 4))

# %%
np.dot(W, input1.T)
# Out:
# array([[-1.16, -5.28]])

# %%
output = relu(np.dot(W, input1.T) + b)

# %%
output
# Out:
# <tf.Tensor: shape=(1, 2), dtype=float64, numpy=array([[0.27, 0.  ]])>

# %% [markdown]
# ### Element-wise operations

# %%
def naive_relu(x):
    assert len(x.shape) == 2
    
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] = max(x[i, j], 0)
    return x

# %% [markdown]
# list.copy() hakkında

# %%
b = [1,2,3,4]
type(b)
# Out:
# list

# %%
a = b
a[0] = 5
b
# Out:
# [5, 2, 3, 4]

# %%
b = [1,2,3,4]
c = b.copy()
c[0] = 5
b
# Out:
# [1, 2, 3, 4]

# %%
array = np.array([[1,-3,5,-7],
                  [-2,4,-6,8]])

# %%
array.shape
# Out:
# (2, 4)

# %%
return_value = naive_relu(array)
return_value
# Out:
# array([[1, 0, 5, 0],
#        [0, 4, 0, 8]])

# %%
def naive_add(x, y):
    assert len(x.shape) == 2
    assert x.shape == y.shape
    
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[i, j]
    return x

# %%
x = np.array([[1, 2, 3],
             [3, -14, 5]])
y = np.array([[2, 4, 6],
             [-7, 8, -19]])

# %%
return_value = naive_add(x,y)
return_value
# Out:
# array([[  3,   6,   9],
#        [ -4,  -6, -14]])

# %%
z = x + y
z
# Out:
# array([[  3,   6,   9],
#        [ -4,  -6, -14]])

# %%
z = np.maximum(z, 0.)
z
# Out:
# array([[3., 6., 9.],
#        [0., 0., 0.]])

# %% [markdown]
# ### Broadcasting

# %%
def naive_add_matrix_and_vector(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[j]
    return x

# %%
x = np.array([[1,2,3],
              [5,6,7]])

y = np.array([2,5,8])

print(len(x.shape), len(y.shape))

return_value = naive_add_matrix_and_vector(x,y)
return_value
# Out:
# 2 1
# array([[ 3,  7, 11],
#        [ 7, 11, 15]])

# %%
z = x + y
z
# Out:
# array([[ 3,  7, 11],
#        [ 7, 11, 15]])

# %%
x
# Out:
# array([[1, 2, 3],
#        [5, 6, 7]])

# %%
z
# Out:
# array([[ 3,  7, 11],
#        [ 7, 11, 15]])

# %%
x = np.random.random((64, 3, 32, 10))
y = np.random.random((32, 10))
z = np.maximum(x, y)
z.shape
# Out:
# (64, 3, 32, 10)

# %%
print("ikinci satır",z[1,:])   # ilk kısım satır
print("birinci kolon",z[:,0])   # ikinci kısım kolon
# Out:
# ikinci satır [[[0.45384786 0.91570939 0.84799885 0.56178145 0.93206713 0.81738778
#    0.50336494 0.31973168 0.63131045 0.36176074]
#   [0.88527232 0.73501036 0.06136211 0.44540921 0.57251685 0.79067569
#    0.65736043 0.14462559 0.47277851 0.77008598]
#   [0.53879348 0.72824068 0.86015181 0.18213785 0.96693091 0.95756757
#    0.99316351 0.81727065 0.88681062 0.94919317]
#   [0.93451505 0.69127307 0.77583018 0.47278255 0.96454587 0.37972938
#    0.39372324 0.55067566 0.26255381 0.44223451]
#   [0.40916657 0.73088804 0.41560452 0.98748364 0.95425833 0.7675575
#    0.9108368  0.85366655 0.76447339 0.92825706]
#   [0.73072234 0.35700653 0.77882442 0.37017196 0.71425241 0.89801887
#    0.92986424 0.53329685 0.96832152 0.93184595]
#   [0.24797516 0.66524816 0.99577261 0.60646943 0.5837213  0.5284074
#    0.42962253 0.61095352 0.99725867 0.75642455]
#   [0.87698501 0.43726703 0.54843697 0.65100973 0.86456805 0.94192676
#    0.84729326 0.715747   0.67859    0.65374489]
#   [0.62748662 0.76824227 0.79197343 0.94697521 0.89060768 0.8344871
#    0.7757834  0.73571218 0.36031119 0.78342754]
#   [0.85418472 0.71894099 0.71498337 0.24669121 0.52532692 0.74795543
#    0.55795345 0.53128336 0.45151177 0.21712757]
#   [0.67302811 0.45587791 0.95066811 0.87995496 0.72428336 0.48287924
#    0.9679366  0.57563689 0.82376351 0.81793706]
#   [0.65687842 0.81314932 0.96247123 0.08439574 0.96709834 0.77592849
#    0.85511351 0.91939426 0.99095041 0.9934876 ]
#   [0.57756477 0.54871043 0.88219183 0.82003552 0.48733948 0.92971656
#    0.95102843 0.54322904 0.56624981 0.82811435]
#   [0.63187532 0.26869195 0.7822695  0.80484564 0.75467333 0.58665236
#    0.89700136 0.90217274 0.77329089 0.66834663]
#   [0.62675341 0.72407433 0.80322285 0.94929561 0.7553769  0.36259725
#    0.69973186 0.63581625 0.58738089 0.47364023]
#   [0.86103318 0.51771461 0.82981445 0.67306493 0.57347117 0.85662987
#    0.83435661 0.92496939 0.53902328 0.46708363]
#   [0.05173655 0.65365261 0.66514494 0.75598299 0.96225448 0.509678
#    0.69644003 0.98812373 0.37580636 0.90850268]
#   [0.89936867 0.31048824 0.65423933 0.79460112 0.82838053 0.95571841
#    0.42710527 0.77425367 0.77261693 0.93617503]
#   [0.61920902 0.83415926 0.92652427 0.98923293 0.28356136 0.54114845
#    0.80161712 0.82012032 0.96601839 0.68654792]
#   [0.55105214 0.95483097 0.85423845 0.8884638  0.56372783 0.63823604
#    0.44222757 0.66110698 0.66517935 0.69767838]
#   [0.98318172 0.99150655 0.75303094 0.57244517 0.83497314 0.36967087
#    0.98319421 0.71283919 0.8310579  0.67017348]
#   [0.98167063 0.37093712 0.3765519  0.47091276 0.58664971 0.68450655
#    0.449321   0.89141049 0.19041266 0.34751542]
#   [0.36495267 0.69039868 0.689333   0.73659062 0.60664358 0.11831075
#    0.84710139 0.61718225 0.641207   0.17462614]
#   [0.80216905 0.26501813 0.62463782 0.8531065  0.26930255 0.93817729
#    0.94401199 0.94675117 0.48246333 0.36296445]
#   [0.48250565 0.68592782 0.90913533 0.59041252 0.83095803 0.87761799
#    0.95816288 0.70284644 0.60312371 0.98014895]
#   [0.67824294 0.72073288 0.92948702 0.30821203 0.85223985 0.44615806
#    0.68356753 0.78591061 0.98106081 0.76657137]
#   [0.69956949 0.98674651 0.95109593 0.97040205 0.7734724  0.86646578
#    0.32618872 0.63970996 0.94519371 0.27323576]
#   [0.90080259 0.62886202 0.19807172 0.6988618  0.42942716 0.90641586
#    0.44648004 0.85900534 0.96121999 0.94351501]
#   [0.33572311 0.69470797 0.79741213 0.43784267 0.72814866 0.64841618
#    0.52606109 0.74963364 0.27223299 0.82368924]
#   [0.33827185 0.99724062 0.19454595 0.81198288 0.34851743 0.18994272
#    0.1865957  0.497202   0.23104587 0.91187855]
#   [0.53145647 0.50807315 0.74729859 0.98284184 0.98338078 0.5708245
#    0.56517529 0.27213754 0.33501014 0.61394588]
#   [0.61014452 0.31552825 0.61171891 0.38347878 0.9604343  0.5831061
#    0.47617749 0.38261814 0.65706939 0.72515296]]
#
#  [[0.92525107 0.91570939 0.84799885 0.56178145 0.93206713 0.88548772
#    0.67288001 0.65396055 0.40582221 0.69973498]
#   [0.63403255 0.54286262 0.82626251 0.75102181 0.32514501 0.79067569
#    0.26228728 0.89203921 0.47277851 0.77008598]
#   [0.53879348 0.72824068 0.86015181 0.99911303 0.96693091 0.95756757
#    0.99316351 0.64757639 0.88681062 0.94919317]
#   [0.93451505 0.99599179 0.93443466 0.70442724 0.56699678 0.91945701
#    0.92318674 0.54274977 0.77612055 0.62057058]
#   [0.66347007 0.18728396 0.41560452 0.89029431 0.63878663 0.78251261
#    0.9108368  0.96904169 0.63934794 0.92825706]
#   [0.43421786 0.35967505 0.77882442 0.36216281 0.41025362 0.89801887
#    0.83630635 0.97881563 0.4161745  0.95266597]
#   [0.37810067 0.98389509 0.80646166 0.88518022 0.344115   0.5284074
#    0.42962253 0.60026438 0.82994883 0.75642455]
#   [0.87698501 0.98783535 0.52731624 0.76553716 0.64666657 0.6293772
#    0.84729326 0.95494066 0.89483648 0.65374489]
#   [0.62748662 0.76824227 0.61778506 0.08871989 0.63861302 0.8344871
#    0.7757834  0.72839217 0.36031119 0.57276306]
#   [0.85418472 0.71894099 0.71498337 0.8116667  0.85087569 0.74795543
#    0.49141332 0.91877288 0.55435429 0.10499862]
#   [0.56268562 0.37636253 0.95066811 0.41461978 0.68298105 0.97682754
#    0.9679366  0.71725598 0.78032301 0.81793706]
#   [0.65687842 0.81314932 0.96247123 0.35213862 0.96709834 0.7268392
#    0.59722461 0.46532244 0.99095041 0.96908206]
#   [0.6831803  0.54871043 0.82442857 0.62671296 0.51967851 0.72387213
#    0.73299449 0.66547078 0.95379251 0.82811435]
#   [0.59258993 0.90234183 0.88214099 0.81171682 0.75467333 0.78155659
#    0.31402883 0.73633004 0.68664576 0.66834663]
#   [0.1788356  0.68024961 0.80322285 0.94929561 0.95975962 0.53165894
#    0.69973186 0.70072996 0.29573292 0.25987503]
#   [0.86103318 0.83418811 0.70727468 0.50423844 0.940579   0.85662987
#    0.83435661 0.31993115 0.58484334 0.83089429]
#   [0.38141895 0.65365261 0.66514494 0.75598299 0.05058866 0.86039889
#    0.76441777 0.98812373 0.34253291 0.77115029]
#   [0.89936867 0.88016996 0.65423933 0.6776162  0.74758361 0.95571841
#    0.42710527 0.77425367 0.77261693 0.88807416]
#   [0.51755718 0.83415926 0.44770347 0.98923293 0.39314532 0.87374137
#    0.81722327 0.99380136 0.96601839 0.94183698]
#   [0.55105214 0.90098437 0.85423845 0.17880201 0.48580313 0.48919294
#    0.43139645 0.23087745 0.47836719 0.69767838]
#   [0.88253695 0.99150655 0.1234866  0.75493619 0.83497314 0.42062105
#    0.52632022 0.71283919 0.89471818 0.62602235]
#   [0.98167063 0.52828399 0.37717153 0.33948463 0.58664971 0.73593367
#    0.449321   0.57396323 0.67958644 0.34751542]
#   [0.39569373 0.69039868 0.77208117 0.13045233 0.60664358 0.39630557
#    0.84710139 0.61718225 0.69924928 0.50844195]
#   [0.80216905 0.24979156 0.85524061 0.47212217 0.26930255 0.93817729
#    0.78399636 0.54552744 0.70434933 0.36296445]
#   [0.92080996 0.65701247 0.90913533 0.76404248 0.83095803 0.49224821
#    0.95816288 0.70284644 0.65040681 0.98014895]
#   [0.98664184 0.39502961 0.80374719 0.99088569 0.85223985 0.49106955
#    0.76605389 0.78953287 0.34133058 0.65152015]
#   [0.43785565 0.53409179 0.95109593 0.97040205 0.81605177 0.88641942
#    0.67615156 0.57048201 0.94519371 0.31415612]
#   [0.58136359 0.89415354 0.19807172 0.6988618  0.3111051  0.77238423
#    0.41501479 0.8071238  0.50830604 0.94351501]
#   [0.89481557 0.39748029 0.89647032 0.80554277 0.88084184 0.64841618
#    0.52817748 0.74963364 0.55880647 0.90605837]
#   [0.76946427 0.99724062 0.63263742 0.79814688 0.6006757  0.80920683
#    0.79727443 0.59439187 0.25173175 0.84763212]
#   [0.53145647 0.99025786 0.74223637 0.98284184 0.82372723 0.22151943
#    0.36763949 0.27213754 0.97002907 0.95089453]
#   [0.98578779 0.960096   0.96063021 0.48772232 0.76135494 0.31293808
#    0.41992595 0.38261814 0.65706939 0.70709885]]
#
#  [[0.95222424 0.91570939 0.84799885 0.56178145 0.93206713 0.52481807
#    0.30979628 0.79189052 0.25826153 0.36176074]
#   [0.41260951 0.54286262 0.09277146 0.44540921 0.59998034 0.79067569
#    0.88578581 0.64492586 0.47277851 0.93076275]
#   [0.92244615 0.72824068 0.86015181 0.97525914 0.96693091 0.95756757
#    0.99316351 0.79438602 0.88681062 0.94919317]
#   [0.93451505 0.69127307 0.54405191 0.22586234 0.56699678 0.58475703
#    0.16423177 0.94106281 0.74499258 0.44223451]
#   [0.78880472 0.18728396 0.77711129 0.6597334  0.63878663 0.89564743
#    0.9108368  0.26694585 0.63934794 0.92825706]
#   [0.70791853 0.61802795 0.77882442 0.14919745 0.68178025 0.89801887
#    0.52275664 0.99309035 0.64536422 0.93184595]
#   [0.2135095  0.92338405 0.80646166 0.60646943 0.8682889  0.5284074
#    0.42962253 0.70536319 0.79999576 0.75642455]
#   [0.87698501 0.41460473 0.99953329 0.86476574 0.85015184 0.23245482
#    0.84729326 0.715747   0.86005644 0.65374489]
#   [0.62748662 0.83072626 0.76018023 0.22528579 0.61099908 0.8344871
#    0.7757834  0.72839217 0.93823532 0.50212309]
#   [0.95168218 0.71894099 0.71498337 0.51969861 0.45723441 0.74795543
#    0.26295657 0.53128336 0.42867348 0.41384923]
#   [0.83549674 0.69503537 0.95066811 0.56870272 0.8413513  0.83365921
#    0.99314114 0.22910696 0.78032301 0.81793706]
#   [0.65687842 0.81314932 0.96247123 0.82977457 0.96709834 0.68757146
#    0.44366141 0.50601218 0.99095041 0.94068909]
#   [0.68776944 0.54871043 0.78774798 0.60382314 0.67583715 0.72387213
#    0.09196554 0.65910406 0.91190446 0.82811435]
#   [0.67496708 0.26869195 0.69810024 0.80789141 0.75467333 0.58665236
#    0.4743435  0.73633004 0.17541578 0.66834663]
#   [0.95445526 0.68024961 0.80322285 0.94929561 0.33001043 0.37896682
#    0.71589293 0.63581625 0.05220908 0.61743697]
#   [0.9763261  0.49160055 0.70727468 0.40671336 0.59273023 0.85662987
#    0.83435661 0.48124056 0.45545507 0.40469064]
#   [0.42453272 0.93665887 0.66514494 0.75598299 0.40318141 0.24766479
#    0.85452134 0.98812373 0.85662915 0.77115029]
#   [0.89936867 0.29006998 0.93809612 0.6776162  0.74758361 0.95571841
#    0.42710527 0.77425367 0.79023986 0.41262801]
#   [0.30810655 0.83415926 0.38742249 0.98923293 0.84459366 0.54114845
#    0.67188421 0.82029913 0.96601839 0.68654792]
#   [0.58649986 0.90098437 0.85423845 0.16532193 0.97164672 0.48919294
#    0.67657207 0.61657539 0.47836719 0.69767838]
#   [0.88253695 0.99150655 0.78097535 0.99648868 0.83497314 0.23534413
#    0.92933853 0.71283919 0.55632195 0.72342332]
#   [0.98167063 0.19208194 0.95390503 0.86383235 0.58664971 0.69994452
#    0.75459713 0.37051417 0.74640014 0.77382091]
#   [0.93992935 0.69039868 0.689333   0.13045233 0.67106301 0.31319207
#    0.91004908 0.61718225 0.90010611 0.87625378]
#   [0.80216905 0.58851909 0.82038191 0.75060959 0.41576037 0.93817729
#    0.93342426 0.9974789  0.98983829 0.76198787]
#   [0.73243761 0.65701247 0.90913533 0.94137882 0.83095803 0.52269597
#    0.95816288 0.70284644 0.27130505 0.98014895]
#   [0.98334989 0.97003696 0.86080922 0.39063955 0.85223985 0.70496364
#    0.68356753 0.11704466 0.67678412 0.85311512]
#   [0.75930212 0.68370319 0.95109593 0.97040205 0.7734724  0.73538718
#    0.67196842 0.7070409  0.94519371 0.40626278]
#   [0.58136359 0.19862767 0.26031175 0.7927177  0.63836801 0.62169518
#    0.44943621 0.8071238  0.1358856  0.94351501]
#   [0.75459032 0.93251737 0.79741213 0.916348   0.72814866 0.64841618
#    0.52606109 0.74963364 0.27223299 0.54710587]
#   [0.06441244 0.99724062 0.9313937  0.79814688 0.39772038 0.18994272
#    0.1865957  0.497202   0.74383374 0.64259789]
#   [0.76902433 0.50807315 0.78607138 0.98284184 0.45274015 0.63873561
#    0.27151424 0.27213754 0.33501014 0.61394588]
#   [0.61014452 0.7642393  0.35562389 0.93515159 0.76135494 0.35156486
#    0.41992595 0.98523921 0.65706939 0.41369386]]]
# birinci kolon [[[0.70629543 0.91570939 0.84799885 ... 0.31973168 0.27025394 0.45857772]
#   [0.41260951 0.54286262 0.6719513  ... 0.4071745  0.77259507 0.94155121]
#   [0.53879348 0.72824068 0.86015181 ... 0.71710061 0.88681062 0.94919317]
#   ...
#   [0.39721269 0.99724062 0.46563073 ... 0.93247924 0.72223794 0.89608856]
#   [0.53145647 0.90291295 0.66356647 ... 0.27213754 0.66998538 0.78569742]
#   [0.88770599 0.28901232 0.35562389 ... 0.94869231 0.65706939 0.41369386]]
#
#  [[0.45384786 0.91570939 0.84799885 ... 0.31973168 0.63131045 0.36176074]
#   [0.88527232 0.73501036 0.06136211 ... 0.14462559 0.47277851 0.77008598]
#   [0.53879348 0.72824068 0.86015181 ... 0.81727065 0.88681062 0.94919317]
#   ...
#   [0.33827185 0.99724062 0.19454595 ... 0.497202   0.23104587 0.91187855]
#   [0.53145647 0.50807315 0.74729859 ... 0.27213754 0.33501014 0.61394588]
#   [0.61014452 0.31552825 0.61171891 ... 0.38261814 0.65706939 0.72515296]]
#
#  [[0.87593645 0.95476951 0.84799885 ... 0.75088689 0.18886495 0.84309538]
#   [0.41260951 0.54286262 0.78802715 ... 0.36647242 0.76095317 0.77008598]
#   [0.53879348 0.72824068 0.86015181 ... 0.62833489 0.88681062 0.94919317]
#   ...
#   [0.71355859 0.99724062 0.31353621 ... 0.72059864 0.55372932 0.67327586]
#   [0.53145647 0.98529301 0.30829822 ... 0.69447675 0.33501014 0.61394588]
#   [0.61014452 0.28901232 0.35562389 ... 0.6033769  0.65706939 0.68551808]]
#
#  ...
#
#  [[0.39852413 0.91570939 0.84799885 ... 0.99551809 0.78487504 0.62481098]
#   [0.41260951 0.91865366 0.91106757 ... 0.24413655 0.47277851 0.77008598]
#   [0.53879348 0.72824068 0.86015181 ... 0.67898583 0.91363607 0.94919317]
#   ...
#   [0.40283641 0.99724062 0.76560823 ... 0.497202   0.87656099 0.53596994]
#   [0.95155274 0.50807315 0.33399649 ... 0.27213754 0.33501014 0.62048666]
#   [0.61014452 0.88152072 0.35562389 ... 0.46467089 0.81501165 0.73581406]]
#
#  [[0.99567152 0.91570939 0.84799885 ... 0.31973168 0.84810683 0.56847214]
#   [0.41260951 0.54286262 0.36149312 ... 0.55922303 0.47277851 0.77008598]
#   [0.64402537 0.87844922 0.86015181 ... 0.71022343 0.88681062 0.94919317]
#   ...
#   [0.4016664  0.99724062 0.57663297 ... 0.89621055 0.84432733 0.53596994]
#   [0.95145855 0.50807315 0.58922896 ... 0.76226124 0.98528157 0.61394588]
#   [0.61014452 0.28901232 0.73300982 ... 0.46785256 0.95518584 0.41369386]]
#
#  [[0.89641188 0.91570939 0.84799885 ... 0.31973168 0.47664701 0.36176074]
#   [0.41260951 0.72012015 0.10738873 ... 0.69490045 0.54937661 0.96778345]
#   [0.53879348 0.86752317 0.86015181 ... 0.62833489 0.88681062 0.94919317]
#   ...
#   [0.8749152  0.99724062 0.20442533 ... 0.497202   0.23104587 0.63946684]
#   [0.53145647 0.81022538 0.2652075  ... 0.62086316 0.33501014 0.61394588]
#   [0.61014452 0.28901232 0.82854979 ... 0.70147003 0.65706939 0.76861756]]]

# %% [markdown]
# ### Tensor dot

# %%
x = np.array([[1, 2, 3], [4, 5, 6]])
y = np.array([[2, 4], [6, 8], [10, 12]])
x.shape, y.shape
# Out:
# ((2, 3), (3, 2))

# %%
def naive_matris_dot_matris(x,y):
    assert x.shape[1] == y.shape[0]
    assert y.shape[1] >= 1                #(4,),(,6)
    
    z = x.shape[1]
    x_row = x.shape[0]
    y_column = y.shape[1]
    sum_of_products = 0
    a = np.zeros((x_row, y_column))
    
    for i in range(x_row):
        for j in range(y_column):
            for k in range(z):
                sum_of_products += x[i,k]*y[k,j]  
            a[i,j] = sum_of_products
            sum_of_products = 0
    return a

# %%
return_value = naive_matris_dot_matris(x, y)
return_value
# Out:
# array([[ 44.,  56.],
#        [ 98., 128.]])

# %%
z = np.dot(x, y)
x.shape, y.shape, z.shape, z
# Out:
# ((2, 3),
#  (3, 2),
#  (2, 2),
#  array([[ 44,  56],
#         [ 98, 128]]))

# %%
pd.DataFrame(z)
# Out:
#     0    1
# 0  28   64
# 1  64  154

# %%
x = np.array([[1, 2, 3], [4, 5, 6]])

y = np.array([[2, 4, 6], [8, 10, 12]])

z = np.dot(x, y.T)
z
# Out:
# array([[ 28,  64],
#        [ 64, 154]])

# %%
pd.DataFrame(y.T)
# Out:
#    0   1
# 0  2   8
# 1  4  10
# 2  6  12

# %%
pd.DataFrame(y)
# Out:
#    0   1   2
# 0  2   4   6
# 1  8  10  12

# %%
x = np.array([[1, 2, 3], [4, 5, 6]])

y = np.array([[2, 8], [4, 10], [6, 12]])

z = np.dot(x, y)
y.shape, z.shape, z
# Out:
# ((3, 2),
#  (2, 2),
#  array([[ 28,  64],
#         [ 64, 154]]))

# %%
pd.DataFrame(z)
# Out:
#     0    1
# 0  28   64
# 1  64  154

# %%
def naive_vector_dot(x, y):
    assert len(x.shape) == 1
    assert len(y.shape) == 1
    assert x.shape[0] == y.shape[0]
    
    z = 0.
    for i in range(x.shape[0]):
        z += x[i] * y[i]
    return z

# %%
def naive_matrix_vector_dot(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            z[i] += x[i, j] * y[j]
    return z

# %%
def naive_matrix_vector_dot(x, y):
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        z[i] = naive_vector_dot(x[i, :], y)
    return z

# %%
def naive_matrix_dot(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 2
    assert x.shape[1] == y.shape[0]
    
    z = np.zeros((x.shape[0], y.shape[1]))
    for i in range(x.shape[0]):
        for j in range(y.shape[1]):
            row_x = x[i, :]
            column_y = y[:, j]
            z[i, j] = naive_vector_dot(row_x, column_y)
    return z

# %% [markdown]
# ### Tensor reshaping

# %% [markdown]
# #### train_images = train_images.reshape((60000, 28 * 28))

# %%
x = np.array([[0., 1.],
              [2., 3.],
              [4., 5.]])
x.shape
# Out:
# (3, 2)

# %%
x = x.reshape((6,))
x
# Out:
# array([0., 1., 2., 3., 4., 5.])

# %%
x = x.reshape((2, 3))
x
# Out:
# array([[0., 1., 2.],
#        [3., 4., 5.]])

# %%
x = np.zeros((300, 20))
x = np.transpose(x)
x.shape
# Out:
# (20, 300)

# %% [markdown]
# ### Geometric interpretation of tensor operations

# %% [markdown]
# ### A geometric interpretation of deep learning
